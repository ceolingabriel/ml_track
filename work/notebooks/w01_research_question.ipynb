# %% [markdown]
# <a href="https://colab.research.google.com/github/ceolingabriel/ml_track/blob/main/work/notebooks/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
# The lane chosen was Lane 4: CTR / Engagement Opportunity Scoring. Because the initial analysis of this week proved that the CTR can change drastically by position and content type, the objective then is to
# identify pages that have good visibility in searches but fail to convert into clicks and engagement.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
# Decision: to identify which well positioned pages are having more engagement and should be analyzed first.
# Action: an editor will check this ranked list to review the metadata, adjust the search interest or improve the text's introduction to hold the reader.
# Error Cost: Recommending the wrong page waste hours of the editor work of reviewing a content that reached its limits, resulting in good opportunities ignored.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import os, sys, subprocess

IN_COLAB = "google.colab" in sys.modules
REPO_URL = "https://github.com/flyrank-bih/flyrank-ml-internship-starter"
REPO_DIR = "flyrank-ml-internship-starter"

if IN_COLAB:
    if not os.path.isdir(REPO_DIR):
        subprocess.run(["git", "clone", "--depth", "1", REPO_URL, REPO_DIR], check=True)
    os.chdir(REPO_DIR)
    subprocess.run([sys.executable, "-m", "pip", "install", "-q", "-r", "requirements.txt"], check=True)
else:
    while not os.path.isdir("data/raw") and os.getcwd() != "/":
        os.chdir("..")

print("Working dir:", os.getcwd())
assert os.path.exists("data/raw/content_refresh_anonymized.csv"), "starter CSV not found — are you at the repo root?"
print("Starter data found. You're ready.")

# ====================================
# 3 real numbers
# ====================================
import pandas as pd
df = pd.read_csv("data/raw/content_refresh_anonymized.csv") # load csv

# n1: how many pages are in page 1, but with less than 5% CTR
page_1_low_ctr = df[(df["avg_position"] <= 10) & (df["ctr"] < 0.05)]
print(f"1. {len(page_1_low_ctr)} pages in the Top 10 that have less than 5% CTR.")

# n2: engagement impact in well positioned pages
page_1_low_eng = df[(df["avg_position"] <= 10) & (df["engagement_rate"] < 30.0)]
print(f"2. {len(page_1_low_eng)} pages in the Top 10 have a critical engagement rate, below 30%.")

# n3: wasted traffic volume
high_imp_low_ctr = df[(df["impressions_90d"] >= 5000) & (df["ctr"] < 0.02)]
print(f"3. {len(high_imp_low_ctr)} pages with more than 5000 impressions, losing almost all traffic with less than 2% CTR.")
# Out:
# Working dir: /content/flyrank-ml-internship-starter/flyrank-ml-internship-starter/flyrank-ml-internship-starter/flyrank-ml-internship-starter/flyrank-ml-internship-starter
# Starter data found. You're ready.
# 1. 6083 pages in the Top 10 that have less than 5% CTR.
# 2. 13961 pages in the Top 10 have a critical engagement rate, below 30%.
# 3. 163 pages with more than 5000 impressions, losing almost all traffic with less than 2% CTR.

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
# What we can claim: We can report directional and observational trends regarding which metrics are statistically associated with low CTR or engagement.
# This provides a decision-support model to help prioritize content reviews.

# What we can't claim: We cannot claim to have reverse-engineered or discovered how Google's algorithm works. As well as causal proof that changing a title
# or meta description will guarantee an immediate traffic recovery, as the historical data is being analyzed rather than conducting an isolated test.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
